# %%
# %pip install pandas
# %pip install deep-translator
# %pip install google_trans_new 
# %pip install google-cloud-translate==2.0.1
# %pip install trrex
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.4.1)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (1.22.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: deep-translator in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.7.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deep-translator) (4.10.0)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deep-translator) (2.27.1)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2021.10.8)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google_trans_new in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.1.9)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-cloud-translate==2.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-cloud-translate==2.0.1) (1.31.5)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-cloud-translate==2.0.1) (1.7.2)
# Requirement already satisfied: packaging>=14.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (21.3)
# Requirement already satisfied: protobuf>=3.12.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (3.19.4)
# Requirement already satisfied: pytz in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (2021.3)
# Requirement already satisfied: setuptools>=40.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (58.1.0)
# Requirement already satisfied: six>=1.13.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (1.16.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (1.54.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (2.27.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (1.43.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (4.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from packaging>=14.3->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (3.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (2.10)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.15.0->google-cloud-translate==2.0.1) (0.4.8)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: trrex in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.0.4)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import glob
import pandas as pd
import numpy as np
from pandas import read_csv
from deep_translator import GoogleTranslator
from nltk import word_tokenize
import re
import nltk
import csv
nltk.download('vader_lexicon')
nltk.download('stopwords')
from nltk.corpus import stopwords
import pandas as pd
import trrex as tx
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/cindy/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/cindy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#read csv file

csv = pd.read_csv ('/Users/cindy/Documents/Text mining project/csv_data.csv', encoding="utf8", on_bad_lines='skip', delimiter = ';')
csv

#expand lenght in the future from3 to 4+ comment_filter
# Out:
#          Frontend Order Id                                Improvement comment  \
# 0     AT211208-284662171-R          nicht so viel Text von den Verkäuferinnen
# 1       AT211212-616385534  The dates on your website didnt match the ones...
# 2     AT211213-112753130-R           All good just order the right glasses:))
# 3       AT211214-176453724  It was awesome! I accidentally ordered the lar...
# 4     AT211214-541614582-R                not all of the personel is friendly
# ...                    ...                                                ...
# 1543    US211214-500549351                                      All went well
# 1544    US211217-553973098                                              Price
# 1545    US211220-M56348335  I have progressive lens and the transition is ...
# 1546    US211222-992456671  More round frames. Otherwise, best service and...
# 1547    US220101-872134679                                  A online eye exam
#
#       comment_filter
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# ...               ...
# 1543             True
# 1544             True
# 1545             True
# 1546             True
# 1547             True
#
# [1548 rows x 3 columns]

# %%
#drop columns

csv.drop(csv.columns[2], axis=1, inplace=True)

# %%
#Remove stop words and special characters

stop = stopwords.words('english')
csv["Improvement comment"] = csv["Improvement comment"].apply(lambda x: " ".join(x.lower() for x in str(x).split() if x not in stop))
csv["Improvement comment"] = csv["Improvement comment"].fillna('').astype(str).str.replace(r'[^A-Za-z ]', '', regex=True).replace('', np.nan, regex=False)

csv
# Out:
#          Frontend Order Id                                Improvement comment
# 0     AT211208-284662171-R              nicht viel text von den verkuferinnen
# 1       AT211212-616385534  the dates website didnt match ones got post of...
# 2     AT211213-112753130-R                       all good order right glasses
# 3       AT211214-176453724  it awesome i accidentally ordered large sized ...
# 4     AT211214-541614582-R                                  personel friendly
# ...                    ...                                                ...
# 1543    US211214-500549351                                      all went well
# 1544    US211217-553973098                                              price
# 1545    US211220-M56348335  i progressive lens transition harsh wrong leve...
# 1546    US211222-992456671  more round frames otherwise best service quali...
# 1547    US220101-872134679                                  a online eye exam
#
# [1548 rows x 2 columns]

# %%
#dictionary of keywords: from dataframe to list 

dictionary = pd.read_csv ('/Users/cindy/Documents/Text mining project/NPS_NLP categories.csv', on_bad_lines='skip', delimiter = ',')
dictionary = dictionary.fillna(method='ffill')
dictionary = dictionary.values.tolist()
dictionary  = [val for sublist in dictionary for val in sublist]
dictionary = [item.lower() for item in dictionary]
#dictionary = str(dictionary)

dictionary
# Out:
# ['gdpr',
#  'case',
#  'contact lenses',
#  'phone',
#  'receive',
#  '30',
#  'booking',
#  'happy',
#  'home try-on',
#  'payment',
#  'pd ',
#  'product',
#  'production',
#  'store',
#  'delete my account',
#  'hard case',
#  'contacts',
#  'communication',
#  'return',
#  'exchange',
#  'cancel',
#  'great',
#  'home try',
#  'invoice',
#  'pupillary distance',
#  'quality',
#  'produce',
#  'location',
#  'delete my details',
#  'cleaning',
#  'contacts',
#  'customer service',
#  'ship',
#  'change',
#  'appointment',
#  'good',
#  'try on',
#  'klarna',
#  'ph',
#  'frame',
#  'cut',
#  'employee',
#  'password',
#  'clip',
#  'contacts',
#  'customer experience',
#  'track',
#  'refund',
#  'optician',
#  'thank',
#  'style advice ',
#  'paypal',
#  'pupillary height',
#  'lense',
#  'lead times',
#  'training',
#  'log in',
#  'cleaning kit',
#  'contacts',
#  'e-mail',
#  'delivery',
#  'warranty',
#  'measurement',
#  'nice',
#  'hto',
#  'card',
#  'prescription',
#  'glasses',
#  'open order',
#  'adjustment',
#  'remove my account',
#  'clip-on',
#  'contacts',
#  'clear communication',
#  'carrier',
#  'return',
#  'test',
#  'excellent',
#  'hto',
#  'fee',
#  'optician',
#  'filter',
#  'lenses laboratory ',
#  'staff',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'confusing',
#  'ups',
#  'wrong order',
#  'prescription',
#  'satisfactory',
#  'hto',
#  'debit',
#  'optician',
#  'sun',
#  'producing',
#  'personnel',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'transparant ',
#  'royal mail',
#  'wrong prescription',
#  'optometrist',
#  'perfect',
#  'hto',
#  'check-out',
#  'optician',
#  'fit',
#  'production status',
#  'corona',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'mail contact',
#  'label',
#  'exchange process',
#  'opthalmologist',
#  'satisfied',
#  'hto',
#  'costs',
#  'optician',
#  'coating',
#  'how long is the prodution time',
#  'assistant',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'lead times',
#  'return form',
#  'cancellation',
#  'amazing ',
#  'hto',
#  'charges ',
#  'optician',
#  'polarised',
#  'how long is the prodution time',
#  'opening',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'send',
#  'return label',
#  'eye-test',
#  'good service',
#  'hto',
#  'credit',
#  'optician',
#  'colour',
#  'how long is the prodution time',
#  'adjust',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'deliver',
#  'shipping label',
#  'eye test',
#  'good work',
#  'hto',
#  'credit',
#  'optician',
#  'lens colour',
#  'how long is the prodution time',
#  'opening times',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'postal office',
#  'shipping label',
#  'cancellations',
#  'thank you',
#  'hto',
#  'credit',
#  'optician',
#  'metal',
#  'how long is the prodution time',
#  'opening hours',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'wait',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'acetate ',
#  'how long is the prodution time',
#  'service',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'delivery time',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'screws',
#  'how long is the prodution time',
#  'employees',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'disappointed in the delivery',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'rim',
#  'how long is the prodution time',
#  'clients',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'quicker delivery',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'design',
#  'how long is the prodution time',
#  'advice',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'shipping',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'style',
#  'how long is the prodution time',
#  'advise',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'shipment',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'assortment',
#  'how long is the prodution time',
#  'adjusting',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'shipping updates',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'anti-reflection',
#  'how long is the prodution time',
#  'communication ',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'return form',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'blue light filter',
#  'how long is the prodution time',
#  'customers ',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'return label',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'thin lenses',
#  'how long is the prodution time',
#  'styl advice',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'shipping label',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'nose bridge',
#  'how long is the prodution time',
#  'bad service in store',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'store delivery',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'size',
#  'how long is the prodution time',
#  'customer experience in store',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'home delivery',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'blue light',
#  'how long is the prodution time',
#  'personel',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'track & trace',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'china',
#  'how long is the prodution time',
#  'personnel',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  't&t',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'product quality',
#  'how long is the prodution time',
#  'educated staff',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'tracking',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'lenses',
#  'how long is the prodution time',
#  'store manager',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'send',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'comfort',
#  'how long is the prodution time',
#  'measurements',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'deliver',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'frames',
#  'how long is the prodution time',
#  'shop assistants ',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'postal office',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'sunglasses',
#  'how long is the prodution time',
#  'stores',
#  'delete my personal information',
#  'soft case',
#  'contacts',
#  'phone call',
#  'postal office',
#  'shipping label',
#  'cancellations',
#  'great brand',
#  'hto',
#  'credit',
#  'optician',
#  'sunnies',
#  'how long is the prodution time',
#  'customer care']

# %%
#Translation

translated = []
for row in csv["Improvement comment"]:
    try:
        translated.append(GoogleTranslator(source='auto', target='en').translate(row))
    except:
        translated.append('')
        
csv["Improvement comment"]=translated

csv_2 = csv

# %%
csv = csv_2

# %%
import nltk
nltk.download('punkt')
  

#Tokenize comment

csv["Improvement comment"] = csv["Improvement comment"].apply(word_tokenize)


#csv["Improvement comment"] = csv.apply(lambda row:word_tokenize(csv["Improvement comment"]),axis=1)

# %%
#convert imporvement list into str

csv["Improvement comment"] = [','.join(map(str, l)) for l in csv["Improvement comment"]]

# %%
#Comment column and dictionary comparison

query = tx.make(dictionary, r"\b(", r")\b")

csv["Word"] = csv["Improvement comment"].str.findall(r'{}'.format(query))

# %%
csv

# %%
#drop comment columns

csv.drop(csv.columns[1], axis=1, inplace=True)

# %%
csv

# %%
csv = csv[csv['Word'].map(lambda d: len(d)) > 0]

csv

# %%
#csv.to_csv("data_edited_2.csv", sep='\t', encoding='utf-8')
